# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_regularization.csv")
df.head()
# Out:
#          f1        f2        f3        f4        f5        f6        f7  \
# 0 -0.924357 -0.326536 -1.875007 -1.780626 -0.630143  0.788204  2.792209
# 1  0.001795 -1.285599 -0.726774  0.385711  0.891863  0.599451 -0.140553
# 2  0.956702  2.319330 -0.705012  0.081829  0.330880  0.838491  2.493000
# 3 -0.982294  0.190424  1.082691  0.714610 -1.907808  0.224216  0.156973
# 4 -0.057061 -0.592465 -2.850030 -1.935430  2.002427 -1.012644  1.059950
#
#          f8        f9       f10  ...      f142      f143      f144      f145  \
# 0 -0.772192 -0.450994  0.400000  ...  0.968645 -0.702053 -0.327662 -0.392108
# 1 -0.761760  0.117707  0.333231  ...  0.856399  0.214094 -1.245739  0.173181
# 2  1.227669 -0.785989 -0.920674  ... -0.493001 -0.589365  0.849602  0.357015
# 3  0.556553  0.058984 -1.397118  ...  0.491919 -1.320233  1.831459  1.179440
# 4 -1.000629  0.141596 -0.642776  ...  1.479944  0.077368 -0.861284  1.523124
#
#        f146      f147      f148      f149      f150      target
# ...

# %%
df.columns
# Out:
# Index(['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10',
#        ...
#        'f142', 'f143', 'f144', 'f145', 'f146', 'f147', 'f148', 'f149', 'f150',
#        'target'],
#       dtype='object', length=151)

# %%
X = df.drop(['target'], axis=1)
y = df['target']
X.head()
# Out:
#          f1        f2        f3        f4        f5        f6        f7  \
# 0 -0.924357 -0.326536 -1.875007 -1.780626 -0.630143  0.788204  2.792209
# 1  0.001795 -1.285599 -0.726774  0.385711  0.891863  0.599451 -0.140553
# 2  0.956702  2.319330 -0.705012  0.081829  0.330880  0.838491  2.493000
# 3 -0.982294  0.190424  1.082691  0.714610 -1.907808  0.224216  0.156973
# 4 -0.057061 -0.592465 -2.850030 -1.935430  2.002427 -1.012644  1.059950
#
#          f8        f9       f10  ...      f141      f142      f143      f144  \
# 0 -0.772192 -0.450994  0.400000  ...  0.097078  0.968645 -0.702053 -0.327662
# 1 -0.761760  0.117707  0.333231  ... -0.446515  0.856399  0.214094 -1.245739
# 2  1.227669 -0.785989 -0.920674  ... -0.208122 -0.493001 -0.589365  0.849602
# 3  0.556553  0.058984 -1.397118  ... -0.898415  0.491919 -1.320233  1.831459
# 4 -1.000629  0.141596 -0.642776  ... -0.007973  1.479944  0.077368 -0.861284
#
#        f145      f146      f147      f148      f149      f150
# ...

# %%
#target
y[:5]
# Out:
# 0     10.681366
# 1    -60.163343
# 2    131.226545
# 3   -131.889020
# 4   -138.566956
# Name: target, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

lm = LinearRegression()      # here it is multiple regression bcoz of many features but not polynomial regression
lm.fit(X_train,y_train)
lm.score(X_test, y_test)
# Out:
# 0.740309332825436

# %%
lm.coef_
# Out:
# array([ 30.55781774, -37.31928641,  13.94674088,   0.59896524,
#          4.04529877, -31.2229557 ,  53.7750584 ,  94.01196761,
#        -31.96507418, -11.68558066, -35.98191566,  40.28691868,
#          3.38550529,  -2.39691645, -15.08454784,   6.75782777,
#         20.64681896, -17.09064657,  42.51042171,  65.68613579,
#        -39.85636708,   5.49982994,  46.19015484,  31.83260212,
#         -2.14917727,  -4.34468188,   0.61227512,   3.91441574,
#         -5.05368159,   3.94472442,   3.87934068,  -7.39941753,
#         86.86721637,   0.36710693,  -3.29275862,  -3.09920191,
#          4.40838131,   5.20702532,  -3.51822713,   9.18166569,
#          6.16486179,   5.53084952,  -0.80925019,  -0.75706882,
#         -2.99972321,  -1.331126  ,  -5.33948498,   3.09602785,
#         -1.06379409,   1.61411761, -28.25748777,  38.2119064 ,
#          9.58457362,  -2.53196817,  25.68944241,  23.11524487,
#        -54.17040486, -28.63711038,  19.50282718,  13.58285364,
# ...

# %%
len(lm.coef_)
# Out:
# 150

# %%
lm.intercept_
# Out:
# -3.080373557604231

# %%
#Lasso Regression uses L1 regularization
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, y_train)
lasso_model.score(X_test, y_test)
# Out:
# 0.9901476660336154

# %%
lasso_model.coef_                      # the coefficient values drastically reduced in lasso_model compared to Linear Regression model
# Out:
# array([-0.00000000e+00, -2.44412330e-01,  1.97252435e+01,  0.00000000e+00,
#         3.08713932e+01,  0.00000000e+00,  0.00000000e+00,  5.77703222e+01,
#        -7.94713931e-02,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         3.18993512e+01, -0.00000000e+00,  6.25100957e+00,  7.55194924e+01,
#        -0.00000000e+00,  7.98983405e+00,  0.00000000e+00,  7.48130970e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -2.36105000e-01,
#         7.35506860e+01, -0.00000000e+00, -0.00000000e+00,  3.03345241e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -5.96641418e-01, -0.00000000e+00,  7.18814788e-01,  0.00000000e+00,
#         2.49000405e-01,  2.30764916e-01, -0.00000000e+00, -0.00000000e+00,
# ...

# %%
lasso_model.intercept_
# Out:
# 0.40750894954108396

# %%
#Ridge Regression uses L2 regularization
ridge_model = Ridge(alpha=1.5)
ridge_model.fit(X_train, y_train)
ridge_model.score(X_test, y_test)
# Out:
# 0.9451781077001788

# %%
#Thec hoice between Ridge or Lasso Regression and parameters like alpha is contingent on multiple factors
#and is typically determined through a process of trial and error
